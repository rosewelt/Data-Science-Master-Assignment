# %% [markdown]
# Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
# you have collected data on the amount of time students spend studying for an exam and their final exam
# scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %%
data = {"time_spend": [5,3,4,5,8,1,3,2],
        "final_score": [70,30,40,45,60,10,30,20]
    
}
import pandas as pd
df = pd.DataFrame(data)
df.corr(method='pearson')
# Out:
#              time_spend  final_score
# time_spend     1.000000     0.867746
# final_score    0.867746     1.000000

# %% [markdown]
#  Pearson correlation coefficient states it have positive correclation between these two variables

# %% [markdown]
# Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.

# %%
data = {"time_sleep": [8,4,3,7,8,9,6,5,4,3,2],
        "final_score": [9,5,4,8,9,10,7,6,5,4,3]
    
}
import pandas as pd
df = pd.DataFrame(data)
df.corr(method='spearman')
# Out:
#              time_sleep  final_score
# time_sleep          1.0          1.0
# final_score         1.0          1.0

# %% [markdown]
# Spearman's rank correlation states it have positive correclation  between these two variables

# %% [markdown]
# Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
# exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
# for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.

# %%
import random
number_of_hours=[]
for i in range(50):
    r=random.randint(1,6)
    number_of_hours.append(r)

bmi=[]
for i in range(50):
    r=random.randint(17,32)
    bmi.append(r)
    
bmi.sort()
number_of_hours.sort(reverse=True)
df = pd.DataFrame({'bmi':bmi,'number_of_hours' :number_of_hours},index=None)
df = df.sample(frac = 1)
df
# Out:
#     bmi  number_of_hours
# 16   22                4
# 7    18                6
# 11   19                5
# 20   24                4
# 31   27                3
# 40   30                2
# 4    17                6
# 21   24                4
# 1    17                6
# 46   32                1
# 38   29                2
# 27   26                4
# 18   24                4
# 17   22                4
# 45   32                1
# 35   28                3
# 23   25                4
# 48   32                1
# 6    18                6
# 13   21                5
# 28   26                3
# 44   31                1
# 37   28                2
# 12   19                5
# 29   26                3
# 26   26                4
# 24   25                4
# 33   27                3
# 8    18                5
# 15   21                4
# 36   28                2
# 9    19                5
# 42   31                1
# 49   32                1
# 2    17                6
# 14   21                5
# ...

# %%
df.corr(method='pearson')
# Out:
#                       bmi  number_of_hours
# bmi              1.000000        -0.971707
# number_of_hours -0.971707         1.000000

# %%
df.corr(method='spearman')
# Out:
#                       bmi  number_of_hours
# bmi              1.000000        -0.979928
# number_of_hours -0.979928         1.000000

# %% [markdown]
# Both of them shows negative correlation. That means if the no oh hours increased the bmi will be dereased.

# %% [markdown]
# Q4. A researcher is interested in examining the relationship between the number of hours individuals
# spend watching television per day and their level of physical activity. The researcher collected data on
# both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.

# %%
import random
number_of_hours=[]
for i in range(50):
    r=random.randint(1,6)
    number_of_hours.append(r)

level_of_activity=[]
for i in range(50):
    r=random.randint(17,32)
    level_of_activity.append(r)
    
level_of_activity.sort()
number_of_hours.sort(reverse=True)
df = pd.DataFrame({'level_of_activity':level_of_activity,'number_of_hours' :number_of_hours},index=None)
df = df.sample(frac = 1)
df
# Out:
#     level_of_activity  number_of_hours
# 14                 21                5
# 25                 24                4
# 47                 31                1
# 28                 25                3
# 21                 23                4
# 15                 21                4
# 13                 21                5
# 48                 31                1
# 29                 25                3
# 2                  17                6
# 1                  17                6
# 43                 29                1
# 40                 29                2
# 38                 28                2
# 49                 32                1
# 9                  20                6
# 3                  18                6
# 26                 25                4
# 24                 24                4
# 23                 24                4
# 18                 22                4
# 22                 24                4
# 11                 20                5
# ...

# %%
df.corr(method='pearson')
# Out:
#                    level_of_activity  number_of_hours
# level_of_activity           1.000000        -0.970278
# number_of_hours            -0.970278         1.000000

# %%
df.corr(method='spearman')
# Out:
#                    level_of_activity  number_of_hours
# level_of_activity           1.000000        -0.975406
# number_of_hours            -0.975406         1.000000

# %% [markdown]
# Both of them shows negative correlation. That means if the no oh hours increased the physical activity will be dereased.

# %% [markdown]
# Q5. A survey was conducted to examine the relationship between age and preference for a particular
# brand of soft drink. The survey results are shown below:
# ![image.png](attachment:image.png)

# %% [markdown]
# Q6. A company is interested in examining the relationship between the number of sales calls made per day
# and the number of sales made per week. The company collected data on both variables from a sample of
# 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.
